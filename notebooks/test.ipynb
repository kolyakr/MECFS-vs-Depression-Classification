# %%
import pandas as pd
import numpy as np

data = [
    [0.435644, 0.720930, -0.420455, 0.857143, 0.619048, 0.0, -0.5, -0.629213, 0.314286, -1.0, 1, 4, 0, 0, 0, 0],
    [0.950495, -1.0, 0.943182, -0.333333, 1.047619, 1.666667, 0.0, 0.808989, 0.514286, 0.0, 1, 3, 0, 0, 0, 0],
    [0.039604, -0.372093, -0.079545, -0.190476, 0.0, 2.333333, -5.4, -0.449438, 0.085714, -1.0, 0, 1, 0, 0, 1, 0]
]

columns = [
    'age', 'sleep_quality_index', 'brain_fog_level', 'physical_pain_score', 'stress_level',
    'depression_phq9_score', 'fatigue_severity_scale_score', 'pem_duration_hours',
    'hours_of_sleep_per_night', 'pem_present', 'social_activity_level', 'exercise_frequency',
    'work_status_Partially working', 'work_status_Not working', 'gender_Female',
    'meditation_or_mindfulness_No'
]

df = pd.DataFrame(data, columns=columns)

df
# Out:
#         age  sleep_quality_index  brain_fog_level  physical_pain_score  \
# 0  0.435644             0.720930        -0.420455             0.857143
# 1  0.950495            -1.000000         0.943182            -0.333333
# 2  0.039604            -0.372093        -0.079545            -0.190476
#
#    stress_level  depression_phq9_score  fatigue_severity_scale_score  \
# 0      0.619048               0.000000                          -0.5
# 1      1.047619               1.666667                           0.0
# 2      0.000000               2.333333                          -5.4
#
#    pem_duration_hours  hours_of_sleep_per_night  pem_present  \
# 0           -0.629213                  0.314286         -1.0
# 1            0.808989                  0.514286          0.0
# 2           -0.449438                  0.085714         -1.0
#
#    social_activity_level  exercise_frequency  work_status_Partially working  \
# ...
